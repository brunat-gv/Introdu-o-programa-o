# %% [markdown]
# <a href="https://colab.research.google.com/github/brunat-gv/Introdu-o-programa-o/blob/main/L%C3%A7.rep.2uni_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""1 — Escreva um programa que:
Peça um número inteiro ao usuário. Imprima todos os números de 1 até esse número usando um while."""

num = int(input("Digite um número inteiro: "))
i = 1
while i <= num:
    print(i)
    i += 1

#_______________________________________________________________________________________

"""2 — Escreva um programa que:
Peça um número inteiro. Imprima todos os números pares de 0 até esse número usando um for."""

num = int(input("Digite um número inteiro: "))
for i in range(0, num + 1, 2):
   print(i)

#_______________________________________________________________________________________

"""3 — Escreva um programa que:
Peça 5 números ao usuário. Ao final, mostre a soma desses números.
Obrigatório: usar um laço de repetição."""

soma = 0
for i in range (5):
    valor = int(input("Digite um números:" ))
    soma = soma + valor
print("Este é o resultado da soma desses valores",soma )

#_______________________________________________________________________________________

"""Questão 4 — Escreva um programa que:
Peça um número inteiro positivo. Mostre a tabuada desse número de 1 até 10."""

num = int(input("Digite o número desejado: "))

for i in range ( 1, 11):
    mult = num * i
    print(num,"X", i, "=",mult)

#_______________________________________________________________________________________

"""#Faça um programa que imprima os números de 1 até 10 usando while."""

cont = 1
while cont <= 10:
    print(cont)
    cont  = cont + 1

#________________________________________________________________________________________

"""Peça um número inteiro ao usuário.
Depois, imprima todos os números pares de 0 até esse número usando while."""

num = int(input("Digite um número inteiro: "))
cont = 0
while cont <= num:
    print(cont)
    cont = cont + 2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_474/2513216047.py in <cell line: 0>()
#      25 soma = 0
#      26 for i in range (5):
# ---> 27     valor = int(input("Digite um números:" ))
#      28     soma = soma + valor
#      29 print("Este é o resultado da soma desses valores",soma )
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
